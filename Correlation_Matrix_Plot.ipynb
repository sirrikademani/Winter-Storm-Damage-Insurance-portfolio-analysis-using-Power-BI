# %%
#pip install pandas matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\raja\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\raja\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: seaborn in c:\users\raja\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\raja\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raja\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\raja\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raja\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\raja\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raja\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\raja\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\raja\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\raja\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\raja\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\raja\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Replace 'your_file.csv' with the actual path to your CSV file
file_path = r'C:\Users\raja\Downloads\UpdatedData.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
# Select columns for correlation calculation
selected_columns = [
    'Building Value', 'Other Value', 'Contents Value',
    'Time Element Value', 
    'Stories', 'AAL', 'TIV', 'Age'
]

# Subset the DataFrame with selected columns
df_selected = df[selected_columns]

# %%
df_selected.head()
# Out:
#    Building Value  Other Value  Contents Value  Time Element Value Stories  \
# 0           55503            0          468542               70422    1.00
# 1           70235            0          154807               54244    1.00
# 2           71881            0          394221               45222    1.00
# 3           70601            0          352324               26443    1.00
# 4           91119            0          470613               56129    1.00
#
#        AAL       TIV   Age
# 0   9987.0  594467.0  23.0
# 1   3016.0  279286.0  42.0
# 2   8836.0  511324.0  68.0
# 3   5608.0  449368.0  14.0
# 4  10677.0  617861.0  70.0

# %%
# Calculate the correlation matrix
correlation_matrix = df_selected.corr()
display(correlation_matrix)
# Out:
# C:\Users\raja\AppData\Local\Temp\ipykernel_46876\3217909798.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_selected.corr()
#                     Building Value  Other Value  Contents Value  \
# Building Value            1.000000     0.109122        0.565597
# Other Value               0.109122     1.000000        0.119276
# Contents Value            0.565597     0.119276        1.000000
# Time Element Value        0.617027     0.103952        0.547157
# AAL                       0.575376     0.160467        0.501328
# TIV                       0.888287     0.131777        0.745401
# Age                      -0.005962     0.004711       -0.001844
#
#                     Time Element Value       AAL       TIV       Age
# Building Value                0.617027  0.575376  0.888287 -0.005962
# Other Value                   0.103952  0.160467  0.131777  0.004711
# Contents Value                0.547157  0.501328  0.745401 -0.001844
# Time Element Value            1.000000  0.582031  0.882888 -0.004598
# AAL                           0.582031  1.000000  0.656956  0.215444
# TIV                           0.882888  0.656956  1.000000 -0.005365
# Age                          -0.004598  0.215444 -0.005365  1.000000

# %%
# Plot the correlation matrix using seaborn
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
